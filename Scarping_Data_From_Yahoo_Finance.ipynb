# %% [markdown]
# ## **Scraping Data From Yahoo Finance**

# %% [markdown]
# ## **The library Used**

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from datetime import datetime, timedelta
import yfinance as yf

# %% [markdown]
# ## **Data Collection Method**

# %%
start = datetime(2017,1,1)
end = datetime(2025,9,16)

tckr = '%5EJKSE'

ticker = yf.Ticker(tckr)
data = ticker.history(start=start, end=end, interval='1d')

# %%
data.head()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2017-01-03 00:00:00+07:00  5290.388184  5292.181152  5246.852051  5275.971191
# 2017-01-04 00:00:00+07:00  5270.016113  5312.956055  5249.233887  5301.183105
# 2017-01-05 00:00:00+07:00  5302.632812  5328.490234  5302.632812  5325.503906
# 2017-01-06 00:00:00+07:00  5321.745117  5350.245117  5318.384766  5347.021973
# 2017-01-09 00:00:00+07:00  5350.879883  5360.061035  5307.584961  5316.363770
#
#                              Volume  Dividends  Stock Splits
# Date
# 2017-01-03 00:00:00+07:00  33217000        0.0           0.0
# 2017-01-04 00:00:00+07:00  53111300        0.0           0.0
# 2017-01-05 00:00:00+07:00  77219400        0.0           0.0
# 2017-01-06 00:00:00+07:00  71615300        0.0           0.0
# 2017-01-09 00:00:00+07:00  97010200        0.0           0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2097 entries, 2017-01-03 00:00:00+07:00 to 2025-09-15 00:00:00+07:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          2097 non-null   float64
#  1   High          2097 non-null   float64
#  2   Low           2097 non-null   float64
#  3   Close         2097 non-null   float64
#  4   Volume        2097 non-null   int64
#  5   Dividends     2097 non-null   float64
#  6   Stock Splits  2097 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 131.1 KB

# %%
data.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2097.000000  2097.000000  2097.000000  2097.000000  2.097000e+03
# mean   6397.234179  6429.725727  6359.123632  6394.262783  1.379286e+08
# std     704.727704   704.696925   704.009958   703.506005  7.187943e+07
# min    3937.632080  4123.562012  3911.716064  3937.632080  0.000000e+00
# 25%    5959.964844  5997.637207  5934.804199  5954.396973  7.506340e+07
# 50%    6410.708984  6434.842773  6369.496094  6400.054199  1.345497e+08
# 75%    6934.109863  6966.766113  6896.999023  6926.225098  1.813414e+08
# max    7971.787109  8022.757812  7941.938965  7952.087891  6.150719e+08
#
#        Dividends  Stock Splits
# count     2097.0        2097.0
# mean         0.0           0.0
# std          0.0           0.0
# min          0.0           0.0
# 25%          0.0           0.0
# 50%          0.0           0.0
# 75%          0.0           0.0
# max          0.0           0.0

# %%
# save file to excel
data.to_excel("data.xlsx", index=False)
